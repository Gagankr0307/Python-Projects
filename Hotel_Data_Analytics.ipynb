# %% [markdown]
# #            Data Exploration

# %%
import pandas as pd

# %%
fact_booking = pd.read_csv("C:/Hospitality_Analysis/datasets/fact_bookings.csv")
fact_booking
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
fact_booking.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
fact_booking.shape
# Out:
# (134590, 12)

# %%
fact_booking.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
fact_booking.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
fact_booking.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
fact_booking.booking_platform.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
fact_booking.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
dim_dates = pd.read_csv("C:/Hospitality_Analysis/datasets/dim_date.csv")
dim_hotels = pd.read_csv("C:/Hospitality_Analysis/datasets/dim_hotels.csv")
dim_rooms = pd.read_csv("C:/Hospitality_Analysis/datasets/dim_rooms.csv")
fact_aggregated_bookings = pd.read_csv("C:/Hospitality_Analysis/datasets/fact_aggregated_bookings.csv")

# %% [markdown]
#    # Data Cleaning

# %%
fact_booking.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
fact_booking[fact_booking.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
fact_booking = fact_booking[fact_booking.no_guests>0]

# %%
fact_booking
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
fact_booking.revenue_generated.min(),fact_booking.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
mean,std = fact_booking.revenue_generated.mean(), fact_booking.revenue_generated.std()

# %%
mean,std
# Out:
# (15378.036937686695, 93040.1549314641)

# %%
higher_limit = mean + 3*std
higher_limit
# Out:
# 294498.50173207896

# %%
lower_limit = mean - 3*std
lower_limit
# Out:
# -263742.4278567056

# %%
fact_booking[fact_booking.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
fact_booking[fact_booking.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
fact_booking = fact_booking[fact_booking.revenue_generated<higher_limit]
fact_booking.shape
# Out:
# (134573, 12)

# %%
fact_booking.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = fact_booking.revenue_realized.mean()+3*fact_booking.revenue_realized.std()
higher_limit
# Out:
# 33479.358661845814

# %%
lower_limit = fact_booking.revenue_realized.mean()-3*fact_booking.revenue_realized.std()
lower_limit
# Out:
# -8087.391491611072

# %%
fact_booking[fact_booking.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
fact_booking[fact_booking.room_category == "RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23439+3*9048
# Out:
# 50583

# %%
fact_booking.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# # Data Transformation

# %%
fact_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
25/30
# Out:
# 0.8333333333333334

# %%
fact_aggregated_bookings["occ_percentage"] = fact_aggregated_bookings["successful_bookings"]/fact_aggregated_bookings["capacity"]

# %%
fact_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_percentage
# 0           0.833333
# ...

# %%
fact_aggregated_bookings["occ_percentage"] = fact_aggregated_bookings["occ_percentage"].apply(lambda x: round(x*100, 2) )
fact_aggregated_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_percentage
# 0           83.33
# 1           93.33
# 2           76.67
# 3          157.89
# 4           94.74

# %% [markdown]
# # Insights Generation

# %%
# Average occupancy rate in each of the room category

# %%
fact_aggregated_bookings.groupby("room_category")["occ_percentage"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_percentage, dtype: float64

# %%
#RTI,RT2 name aren't that clear so will gonna merge the coloumn to make clear whether its standard or anything

# %%
dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(fact_aggregated_bookings,dim_rooms,left_on = "room_category",right_on = "room_id")
df.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_percentage room_id room_class
# 0           83.33     RT1   Standard
# 1           93.33     RT1   Standard
# 2           76.67     RT1   Standard
# 3          157.89     RT1   Standard
# 4           94.74     RT1   Standard

# %%
#Now run the same code but instead of fact_aggregated_bookings.groupby and room_category will group the df on the basis of room_class

# %%
df.groupby("room_class")["occ_percentage"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_percentage, dtype: float64

# %%
#There are two coloumn that shows the same data that's room_category and room_id so will drop one of the coloum

# %%
df.drop("room_category",axis = 1,inplace = True)
df.head(4)
# Out:
#    property_id check_in_date  successful_bookings  capacity  occ_percentage  \
# 0        16559      1-May-22                   25      30.0           83.33
# 1        19562      1-May-22                   28      30.0           93.33
# 2        19563      1-May-22                   23      30.0           76.67
# 3        17558      1-May-22                   30      19.0          157.89
#
#   room_id room_class
# 0     RT1   Standard
# 1     RT1   Standard
# 2     RT1   Standard
# 3     RT1   Standard

# %%
# Average occupancy rate by each city

# %%
dim_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
# Now will merge city column to your df

# %%
df = pd.merge(df,dim_hotels,on = "property_id")
df.head(4)
# Out:
#    property_id check_in_date  successful_bookings  capacity  occ_percentage  \
# 0        16559      1-May-22                   25      30.0           83.33
# 1        16559      2-May-22                   20      30.0           66.67
# 2        16559      3-May-22                   17      30.0           56.67
# 3        16559      4-May-22                   21      30.0           70.00
#
#   room_id room_class  property_name category    city
# 0     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 1     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 2     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 3     RT1   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby("city")["occ_percentage"].mean().round(2)
# Out:
# city
# Bangalore    56.59
# Delhi        61.61
# Hyderabad    58.14
# Mumbai       57.94
# Name: occ_percentage, dtype: float64

# %%
df.groupby("city")["occ_percentage"].mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
# When was the occupancy better???weekends or weekdays??

# %%
dim_dates
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
# Will do the same merge the coloumn

# %%
df = pd.merge(df,dim_dates,left_on = "check_in_date",right_on = "date")
df.head(4)
# Out:
#    property_id check_in_date  successful_bookings  capacity  occ_percentage  \
# 0        16559     10-May-22                   18      30.0           60.00
# 1        16559     10-May-22                   25      41.0           60.98
# 2        16559     10-May-22                   20      32.0           62.50
# 3        16559     10-May-22                   13      18.0           72.22
#
#   room_id    room_class  property_name category    city       date  mmm yy  \
# 0     RT1      Standard  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 1     RT2         Elite  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 2     RT3       Premium  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 3     RT4  Presidential  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# 2    W 20  weekeday
# 3    W 20  weekeday

# %%
df.groupby("day_type")["occ_percentage"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_percentage, dtype: float64

# %%
#occupancy for different city on june

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22 = df[df["mmm yy"] == "Jun 22"]
df_june_22.head(3)
# Out:
#       property_id check_in_date  successful_bookings  capacity  \
# 2200        16559     10-Jun-22                   20      30.0
# 2201        16559     10-Jun-22                   26      41.0
# 2202        16559     10-Jun-22                   20      32.0
#
#       occ_percentage room_id room_class  property_name category    city  \
# 2200           66.67     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 2201           63.41     RT2      Elite  Atliq Exotica   Luxury  Mumbai
# 2202           62.50     RT3    Premium  Atliq Exotica   Luxury  Mumbai
#
#            date  mmm yy week no  day_type
# 2200  10-Jun-22  Jun 22    W 24  weekeday
# 2201  10-Jun-22  Jun 22    W 24  weekeday
# 2202  10-Jun-22  Jun 22    W 24  weekeday

# %%
df_june_22.groupby("city")["occ_percentage"].mean().sort_values(ascending = False).round(2)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_percentage, dtype: float64

# %%
August_data = pd.read_csv("C:/Hospitality_Analysis/datasets/new_data_august.csv")

# %%
August_data.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
August_data.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'successful_bookings', 'capacity',
#        'occ_percentage', 'room_id', 'room_class', 'property_name', 'category',
#        'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
August_data.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 14)

# %%
latest_df=pd.concat([df,August_data],ignore_index = False,axis = 0)
latest_df.tail(10)
# Out:
#       property_id check_in_date  successful_bookings  capacity  \
# 6497        18560     31-Jul-22                   34      40.0
# 6498        18560     31-Jul-22                   17      24.0
# 6499        18560     31-Jul-22                   12      15.0
# 0           16559     01-Aug-22                   30      30.0
# 1           19562     01-Aug-22                   21      30.0
# 2           19563     01-Aug-22                   23      30.0
# 3           19558     01-Aug-22                   30      40.0
# 4           19560     01-Aug-22                   20      26.0
# 5           17561     01-Aug-22                   18      26.0
# 6           17564     01-Aug-22                   10      16.0
#
#       occ_percentage room_id    room_class  property_name  category  \
# 6497           85.00     RT2         Elite     Atliq City  Business
# 6498           70.83     RT3       Premium     Atliq City  Business
# ...

# %%
# Print revenue_realized each city

# %%
fact_booking.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
dim_hotels.head(6)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi
# 5        16563   Atliq Palace  Business   Delhi

# %%
df_bookings_all = pd.merge(fact_booking,dim_hotels, on = "property_id" )
df_bookings_all.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
#Print month by month revenue

# %%
dim_dates["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
dim_dates.head(4)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
dim_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
dim_dates["date"] = pd.to_datetime(dim_dates["date"])
dim_dates.head(4)
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_876\1303633992.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dim_dates["date"] = pd.to_datetime(dim_dates["date"])
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday
# 3 2022-05-04  May 22    W 19  weekeday

# %%
dim_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
# Check_in_date Format is D/M/YYYY will change to DD-MM-YY

# %%
def parse_date(date_str):
    for fmt in ('%m/%d/%Y', '%d-%m-%y'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            pass
    return pd.to_datetime(date_str)

# %%
df_bookings_all['check_in_date'] = df_bookings_all['check_in_date'].apply(parse_date)

# %%
df_bookings_all['check_in_date'] = df_bookings_all['check_in_date'].dt.strftime('%m-%d-%y')

# %%
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      01-05-22      2/5/2022
# 1  May012216558RT15        16558     27-04-22      01-05-22      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      01-05-22      3/5/2022
# 3  May012216558RT17        16558     28-04-22      01-05-22      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all['check_in_date'] = pd.to_datetime(df_bookings_all['check_in_date'])
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_876\3298858996.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_bookings_all['check_in_date'] = pd.to_datetime(df_bookings_all['check_in_date'])

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all,dim_dates, left_on = "check_in_date", right_on = "date")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2              10010             10010  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no  day_type
# 0 2022-05-05  May 22    W 19  weekeday
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    389940912
# Jun 22    377191229
# May 22    408375641
# Name: revenue_realized, dtype: int64

# %%
# Revenue realized Per hotel type

# %%
df.tail(4)
# Out:
#       property_id check_in_date  successful_bookings  capacity  \
# 6496        18560     31-Jul-22                   22      30.0
# 6497        18560     31-Jul-22                   34      40.0
# 6498        18560     31-Jul-22                   17      24.0
# 6499        18560     31-Jul-22                   12      15.0
#
#       occ_percentage room_id    room_class property_name  category       city  \
# 6496           73.33     RT1      Standard    Atliq City  Business  Hyderabad
# 6497           85.00     RT2         Elite    Atliq City  Business  Hyderabad
# 6498           70.83     RT3       Premium    Atliq City  Business  Hyderabad
# 6499           80.00     RT4  Presidential    Atliq City  Business  Hyderabad
#
#            date  mmm yy week no day_type
# 6496  31-Jul-22  Jul 22    W 32  weekend
# 6497  31-Jul-22  Jul 22    W 32  weekend
# 6498  31-Jul-22  Jul 22    W 32  weekend
# 6499  31-Jul-22  Jul 22    W 32  weekend

# %%
# Print pie chart for revenue realized per booking platform

# %%
df_bookings_all.groupby("booking_platform")["revenue_realized"].sum().plot(kind = "pie")
# Out:
# <Axes: ylabel='revenue_realized'>
